# %%
# %pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\chann\.conda\envs\tensorflow_env\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: Could not find a suitable TLS CA certificate bundle, invalid path: C:\Program Files\PostgreSQL\16\ssl\certs\ca-bundle.crt
#
# WARNING: There was an error checking the latest version of pip.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import os

# Define paths
base_dir = 'D:\PKG - C-NMC 2019\C-NMC_training_data'
folds = ['fold_0', 'fold_1', 'fold_2']
categories = ['all', 'hem']

# Parameters
img_width, img_height = 150, 150
batch_size = 32
epochs = 10  # Adjust based on your dataset size and available compute

# Data Generators
datagen = ImageDataGenerator(rescale=1.0/255.0, validation_split=0.2)

def create_data_generators(base_dir, folds, categories, img_width, img_height, batch_size):
    train_generators = []
    val_generators = []
    for fold in folds:
        train_data_dir = os.path.join(base_dir, fold)
        train_generator = datagen.flow_from_directory(
            train_data_dir,
            target_size=(img_width, img_height),
            batch_size=batch_size,
            class_mode='binary',
            subset='training'
        )
        val_generator = datagen.flow_from_directory(
            train_data_dir,
            target_size=(img_width, img_height),
            batch_size=batch_size,
            class_mode='binary',
            subset='validation'
        )
        train_generators.append(train_generator)
        val_generators.append(val_generator)
    return train_generators, val_generators

train_generators, val_generators = create_data_generators(base_dir, folds, categories, img_width, img_height, batch_size)

# Define a simple CNN model
def create_model():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Train the model with each fold
for i, (train_generator, val_generator) in enumerate(zip(train_generators, val_generators)):
    print(f"Training with fold {i+1}")
    model = create_model()
    model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // batch_size,
        validation_data=val_generator,
        validation_steps=val_generator.samples // batch_size,
        epochs=epochs
    )
    model.save(f'model_fold_{i+1}.h5')
    print(f"Model for fold {i+1} saved as model_fold_{i+1}.h5")
# Out:
# Found 2822 images belonging to 2 classes.
# Found 705 images belonging to 2 classes.
# Found 2866 images belonging to 2 classes.
# Found 715 images belonging to 2 classes.
# Found 2843 images belonging to 2 classes.
# Found 710 images belonging to 2 classes.
# Training with fold 1
# Epoch 1/10
# 88/88 [==============================] - 164s 2s/step - loss: 0.4694 - accuracy: 0.8065 - val_loss: 0.3828 - val_accuracy: 0.8395
# Epoch 2/10
# 88/88 [==============================] - 102s 1s/step - loss: 0.4399 - accuracy: 0.8176 - val_loss: 0.4126 - val_accuracy: 0.8224
# Epoch 3/10
# 88/88 [==============================] - 100s 1s/step - loss: 0.4323 - accuracy: 0.8168 - val_loss: 0.3941 - val_accuracy: 0.8281
# Epoch 4/10
# 88/88 [==============================] - 78s 883ms/step - loss: 0.4096 - accuracy: 0.8312 - val_loss: 0.4498 - val_accuracy: 0.7955
# Epoch 5/10
# 88/88 [==============================] - 79s 889ms/step - loss: 0.3904 - accuracy: 0.8358 - val_loss: 0.4988 - val_accuracy: 0.7656
# Epoch 6/10
# 88/88 [==============================] - 68s 771ms/step - loss: 0.3402 - accuracy: 0.8602 - val_loss: 0.5011 - val_accuracy: 0.7784
# Epoch 7/10
# 88/88 [==============================] - 71s 803ms/step - loss: 0.2884 - accuracy: 0.8785 - val_loss: 0.6155 - val_accuracy: 0.7074
# Epoch 8/10
# 88/88 [==============================] - 68s 776ms/step - loss: 0.2726 - accuracy: 0.8781 - val_loss: 0.4645 - val_accuracy: 0.7926
# Epoch 9/10
# 88/88 [==============================] - 70s 790ms/step - loss: 0.2293 - accuracy: 0.9061 - val_loss: 0.4456 - val_accuracy: 0.8040
# 88/88 [==============================] - 69s 789ms/step - loss: 0.3731 - accuracy: 0.8381 - val_loss: 0.6588 - val_accuracy: 0.7301
# Epoch 9/10
# 88/88 [==============================] - 75s 859ms/step - loss: 0.3067 - accuracy: 0.8641 - val_loss: 0.8194 - val_accuracy: 0.7017
# Epoch 10/10
# 88/88 [==============================] - 62s 702ms/step - loss: 0.2703 - accuracy: 0.8847 - val_loss: 0.9866 - val_accuracy: 0.6619
# Model for fold 3 saved as model_fold_3.h5

# %% [markdown]
# Converting to single format and training a single model for the same.

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

# Define paths
base_dir = 'D:\PKG - C-NMC 2019\C-NMC_training_data'
folds = ['fold_0', 'fold_1', 'fold_2']
categories = ['all', 'hem']

# Parameters
img_width, img_height = 150, 150
batch_size = 32
epochs = 10

# %%
# Data Generators
datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.1  # 10% validation split
)

# Function to create data generators
def create_data_generators(base_dir, folds, categories, img_width, img_height, batch_size):
    train_generators = []
    val_generators = []
    
    for fold in folds:
        train_data_dir = os.path.join(base_dir, fold)
        train_generator = datagen.flow_from_directory(
            train_data_dir,
            target_size=(img_width, img_height),
            batch_size=batch_size,
            class_mode='binary',  # Assuming binary classification
            subset='training'
        )
        val_generator = datagen.flow_from_directory(
            train_data_dir,
            target_size=(img_width, img_height),
            batch_size=batch_size,
            class_mode='binary',  # Assuming binary classification
            subset='validation'
        )
        train_generators.append(train_generator)
        val_generators.append(val_generator)
    
    return train_generators, val_generators

# Create data generators
train_generators, val_generators = create_data_generators(base_dir, folds, categories, img_width, img_height, batch_size)
# Out:
# Found 3175 images belonging to 2 classes.
# Found 352 images belonging to 2 classes.
# Found 3224 images belonging to 2 classes.
# Found 357 images belonging to 2 classes.
# Found 3199 images belonging to 2 classes.
# Found 354 images belonging to 2 classes.

# %%
# Define the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Output layer, binary classification
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generators[0],  # Using the first fold for training
    steps_per_epoch=train_generators[0].samples // batch_size,
    epochs=epochs,
    validation_data=val_generators[0],  # Using the first fold for validation
    validation_steps=val_generators[0].samples // batch_size
)

# Save the model
model.save('combined_model_bmp.h5')
print("Model saved as combined_model_bmp.h5")
# Out:
# Epoch 1/10
# 99/99 [==============================] - 138s 1s/step - loss: 0.5869 - accuracy: 0.6796 - val_loss: 0.5417 - val_accuracy: 0.6960
# Epoch 2/10
# 99/99 [==============================] - 128s 1s/step - loss: 0.5612 - accuracy: 0.7222 - val_loss: 0.5388 - val_accuracy: 0.7102
# Epoch 3/10
# 99/99 [==============================] - 109s 1s/step - loss: 0.5464 - accuracy: 0.7372 - val_loss: 0.4995 - val_accuracy: 0.7528
# Epoch 4/10
# 99/99 [==============================] - 130s 1s/step - loss: 0.5266 - accuracy: 0.7506 - val_loss: 0.4989 - val_accuracy: 0.7528
# Epoch 5/10
# 99/99 [==============================] - 130s 1s/step - loss: 0.5137 - accuracy: 0.7604 - val_loss: 0.5037 - val_accuracy: 0.7898
# Epoch 6/10
# 99/99 [==============================] - 101s 1s/step - loss: 0.5134 - accuracy: 0.7563 - val_loss: 0.4993 - val_accuracy: 0.7812
# Epoch 7/10
# 99/99 [==============================] - 121s 1s/step - loss: 0.5273 - accuracy: 0.7537 - val_loss: 0.5838 - val_accuracy: 0.7443
# Epoch 8/10
# 99/99 [==============================] - 102s 1s/step - loss: 0.5037 - accuracy: 0.7703 - val_loss: 0.4775 - val_accuracy: 0.7841
# Epoch 9/10
# 99/99 [==============================] - 100s 1s/step - loss: 0.5063 - accuracy: 0.7661 - val_loss: 0.4635 - val_accuracy: 0.7983
# Epoch 10/10
# 99/99 [==============================] - 112s 1s/step - loss: 0.4810 - accuracy: 0.7811 - val_loss: 0.5211 - val_accuracy: 0.7614
# Model saved as combined_model_bmp.h5

# %%
# Evaluation on test set (fold_1)
test_generator = datagen.flow_from_directory(
    os.path.join(base_dir, folds[1]),  # Use fold_1 for testing
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',  # Assuming binary classification
    subset='validation',  # Use 'validation' subset
    shuffle=False  # Keep data order to match predictions with labels
)

# Evaluate the model
loss, accuracy = model.evaluate(test_generator)

# Predict probabilities for the test set
y_pred_prob = model.predict(test_generator)

# Convert probabilities to class labels
y_pred = (y_pred_prob > 0.5).astype(int)

# Extract true labels
y_true = test_generator.classes

# Calculate recall (sensitivity) using sklearn's recall_score
from sklearn.metrics import recall_score

recall = recall_score(y_true, y_pred)

print(f"Recall: {recall:.4f}")
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Found 357 images belonging to 2 classes.
# 12/12 [==============================] - 6s 535ms/step - loss: 0.4869 - accuracy: 0.7703
# 12/12 [==============================] - 6s 480ms/step
# Recall: 0.4138
# Test Loss: 0.4869
# Test Accuracy: 0.7703

# %% [markdown]
# Completed the entire process with purely one folder

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical
from PIL import Image
from skimage.util import view_as_blocks

def load_test_data(folder, image_patch_size):
    image_dataset = []
    labels = []

    for file_name in os.listdir(folder):
        if file_name.endswith('.bmp'):
            image_path = os.path.join(folder, file_name)
            print(f'Loading test image: {image_path}')
            image = cv2.imread(image_path, 1)
            if image is not None:
                size_x = (image.shape[1] // image_patch_size) * image_patch_size
                size_y = (image.shape[0] // image_patch_size) * image_patch_size
                image = Image.fromarray(image)
                image = image.crop((0, 0, size_x, size_y))
                image = np.array(image)
                patched_images = view_as_blocks(image, (image_patch_size, image_patch_size, 3))
                for i in range(patched_images.shape[0]):
                    for j in range(patched_images.shape[1]):
                        individual_patched_image = patched_images[i, j, :, :]
                        image_dataset.append(individual_patched_image)
                        labels.append(0)  # Assuming all images are of the same class (label 0)
            else:
                print(f'Failed to load test image: {image_path}')

    image_dataset = np.array(image_dataset)
    labels = np.array(labels)
    labels = to_categorical(labels, 2)  # Convert labels to categorical if needed

    return image_dataset, labels

# Define your test folders
test_folder1 = "D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data"
test_folder2 = "D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data"

# Assuming image_patch_size is defined elsewhere in your code
image_patch_size = 128

# Load test data from both folders
test_image_dataset1, test_labels1 = load_test_data(test_folder1, image_patch_size)
test_image_dataset2, test_labels2 = load_test_data(test_folder2, image_patch_size)
# Out:
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\10.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\100.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1000.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1001.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1002.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1003.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1004.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1005.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1006.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1007.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1008.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1009.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\101.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1010.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1011.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1012.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1013.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1014.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1015.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1016.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1017.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1018.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1019.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\102.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1020.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1021.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1022.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1023.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1024.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1025.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1026.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1027.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1028.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1029.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\103.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1030.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1031.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1032.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1033.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1034.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1035.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1036.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1037.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1038.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\1039.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\104.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_prelim_phase_data\
bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data\987.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data\988.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data\989.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data\99.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data\990.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data\991.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data\992.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data\993.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data\994.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data\995.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data\996.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data\997.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data\998.bmp
# Loading test image: D:\PKG - C-NMC 2019\C-NMC_test_final_phase_data\999.bmp

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import array_to_img

# Function to preprocess test data
def preprocess_test_data(test_data, target_size=(150, 150)):
    preprocessed_data = []
    
    for batch in test_data:
        batch_preprocessed = []
        for patch in batch:
            img = array_to_img(patch.astype('uint8'))  # Convert to PIL Image
            img = img.resize(target_size)
            image = np.array(img)
            batch_preprocessed.append(image)
        
        preprocessed_data.append(np.array(batch_preprocessed))
        
    return np.array(preprocessed_data)

# Assuming image_patch_size is defined elsewhere in your code
image_patch_size = 128

# Preprocess test datasets
test_image_dataset1_processed = preprocess_test_data(test_image_dataset1)
test_image_dataset2_processed = preprocess_test_data(test_image_dataset2)

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import numpy as np

# Define a function to evaluate the model
def evaluate_model(model_path, test_data, test_labels):
    model = load_model(model_path)
    # Evaluate the model
    loss, accuracy = model.evaluate(test_data, test_labels, verbose=1)
    print(f'Model evaluation - Loss: {loss}, Accuracy: {accuracy}')

# Assuming paths to your trained model files
model_path_fold1 = 'model_fold_1.h5'
model_path_fold2 = 'model_fold_2.h5'

# Reshape test_labels to match model output shape (None, 1)
test_labels1_single = test_labels1[:, 1]  # Assuming class 'hem' is encoded as 1
test_labels2_single = test_labels2[:, 1]  # Assuming class 'hem' is encoded as 1

# Evaluate model on fold 1
evaluate_model(model_path_fold1, np.squeeze(test_image_dataset1_processed), test_labels1_single)

# Evaluate model on fold 2
evaluate_model(model_path_fold2, np.squeeze(test_image_dataset2_processed), test_labels2_single)
# Out:
# 526/526 [==============================] - 104s 197ms/step - loss: 100.1058 - accuracy: 0.7690
# Model evaluation - Loss: 100.10580444335938, Accuracy: 0.7690293192863464
# 1293/1293 [==============================] - 257s 198ms/step - loss: 220.3284 - accuracy: 0.1612
# Model evaluation - Loss: 220.32838439941406, Accuracy: 0.16115622222423553

# %%
import numpy as np
from tensorflow.keras.models import load_model
from sklearn.metrics import recall_score
from tensorflow.keras.preprocessing.image import array_to_img
import os
import cv2
from tensorflow.keras.utils import to_categorical
from PIL import Image
from skimage.util import view_as_blocks

# Function to calculate recall
def calculate_recall(model_path, test_data, test_labels):
    # Load the model
    model = load_model(model_path)
    
    # Make predictions
    predictions = model.predict(test_data)
    predicted_classes = np.argmax(predictions, axis=1)
    
    # Check if there are any positive samples in the test labels
    print(f'Number of positive samples in test labels: {np.sum(test_labels == 1)}')
    
    # Calculate recall
    recall = recall_score(test_labels, predicted_classes, zero_division=1)
    print(f'Recall: {recall:.2%}')
    
    return recall

# Paths to your trained model files
model_path_fold1 = 'model_fold_1.h5'
model_path_fold2 = 'model_fold_2.h5'

# Calculate recall for fold 1
recall_fold1 = calculate_recall(model_path_fold1, np.squeeze(test_image_dataset1_processed), test_labels1_single)

# Calculate recall for fold 2
recall_fold2 = calculate_recall(model_path_fold2, np.squeeze(test_image_dataset2_processed), test_labels2_single)
# Out:
# 526/526 [==============================] - 66s 125ms/step
# Number of positive samples in test labels: 0
# Recall: 100.00%
# 1293/1293 [==============================] - 174s 135ms/step
# Number of positive samples in test labels: 0
# Recall: 100.00%
